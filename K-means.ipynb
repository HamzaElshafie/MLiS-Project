# %%
#Loading the required modules
 
import numpy as np
from scipy.spatial.distance import cdist 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
 
#Defining our function 
def kmeans(x, k, no_of_iterations):
    # Randomly choosing centroids
    idx = np.random.choice(len(x), k, replace=False)
    centroids = x[idx, :]

    # Calculate distances between data points and centroids
    for _ in range(no_of_iterations):
        distances = np.sqrt(np.sum((x[:, np.newaxis] - centroids) ** 2, axis=2))

        # Assign each data point to the closest centroid
        points = np.argmin(distances, axis=1)

        # Update centroids
        centroids = np.array([x[points == idx].mean(axis=0) for idx in range(k)])

    return points




#hopefully find 3 or less features so can extract then features for x and then use them in the k-means
#x_imputed = , extract the important features



label = kmeans(x, 2, 10000)

u_labels = np.unique(label)

fig = plt.figure(figsize=(11, 11))
ax = fig.add_subplot(111, projection='3d')

for i in u_labels:
    ax.scatter(x[label == i, 0], x[label == i, 1], x[label == i, 2], label=i)

ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')

plt.legend()
plt.show()
